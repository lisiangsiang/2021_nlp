# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
num=[1]
for i in num:
    url = 'https://movies.yahoo.com.tw/movieinfo_main/'+str(i)
    resp = requests.get(url)
    resp.encoding = 'utf-8'
    print(resp.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh_TW">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1">
#   <meta http-equiv="content-type" content="text/html; charset=utf-8">
#   <meta property="fb:app_id" content="501887343352051">
#   <meta property="og:site_name" content="Yahoo奇摩電影">
#   <link rel="icon" href="/favicon.ico?v=2" />
#
#     <title>一世狂野 Blow - Yahoo奇摩電影</title>
# <meta name="twitter:title" content="一世狂野 Blow - Yahoo奇摩電影">
#   <meta property="og:title" content="一世狂野 Blow - Yahoo奇摩電影">
#
# <link rel="canonical" href="https://movies.yahoo.com.tw/movieinfo_main.html/id=1">
# <meta property="og:url" content="https://movies.yahoo.com.tw/movieinfo_main.html/id=1">
#   <link rel="amphtml" href="https://movies.yahoo.com.tw/amp/movieinfo_main.html/id=1">
#
# <meta name="twitter:description" content="喬治戎格一生都在追求所謂的美國夢，也就是享受美好富裕的生活，但是他卻不願像他父親那樣一輩子都只是個出賣勞力的建築工人。於是他搬到陽光明媚的加州，靠著販賣大麻賺錢，起初，他販毒只是為了享受自由自在的生活">
# <meta name="description" content="喬治戎格一生都在追求所謂的美國夢，也就是享受美好富裕的生活，但是他卻不願像他父親那樣一輩子都只是個出賣勞力的建築工人。於是他搬到陽光明媚的加州，靠著販賣大麻賺錢，起初，他販毒只是為了享受自由自在的生活">
#
#   <meta property="og:description" content="喬治戎格一生都在追求所謂的美國夢，也就是享受美好富裕的生活，但是他卻不願像他父親那樣一輩子都只是個出賣勞力的建築工人。於是他搬到陽光明媚的加州，靠著販賣大麻賺錢，起初，他販毒只是為了享受自由自在的生活">
#
# <meta name="twitter:image" content="https://movies.yahoo.com.tw/y/r/w420/vu/movies/fp/mpost/00/01/1.jpg">
# <meta property="og:image" content="https://movies.yahoo.com.tw/y/r/w420/vu/movies/fp/mpost/00/01/1.jpg">
# <meta name="twitter:image:src" content="https://movies.yahoo.com.tw/y/r/w420/vu/movies/fp/mpost/00/01/1.jpg">
# <meta name="keywords" content="電影, yahoo奇摩電影, 時刻表, 新片, 預告片, 網友滿意榜, yahoo 電影, 劇照, 線上訂票, 票房, 台北票房, 全美票房, 排行榜, 戲院, 片名, 電視, 熱映中, 本週新片, 海報, 滿意度, 期待度">
#   <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "Movie",
#     "name": "一世狂野 Blow",
#     "image": "https://movies.yahoo.com.tw/y/r/w420/vu/movies/fp/mpost/00/01/1.jpg",
#     "aggregateRating": {
#       "@type": "AggregateRating",
#       "ratingCount": 16,
#       "bestRating": "5.0",
#       "worstRating": "1.0",
#       "ratingValue": "3.6"
#       }
#     }
#   </script>
#   <link rel="stylesheet" href="/build/css/app.css?id=5112aeac128d78f841b1&amp;r=1614354020">
#   <meta name="oath:guce:consent-host" content="guce.yahoo.com.tw"/>
#
# <!-- Consent Manager Tag : Script -->
# <script type="text/javascript" src="https://consent.cmp.oath.com/cmp.js" async></script>
#
# <!-- Consent Manager Tag : Stubbed (updated 2018-04-27T17:00) -->
# <script type="text/javascript">
#     (function () {
#         var gdprAppliesGlobally = false;
#
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body && document.body.firstChild) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#
#                       iframe.style.display = 'none';
# 			  iframe.height = iframe.width = 0;
#
#                     iframe.name = '__cmpLocator';
#                     body.insertBefore(iframe, body.firstChild);
#                 } else {
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#
#         addFrame();
#
#         function stubCMP() {
#             var b = arguments;
#             __cmp.a = __cmp.a || [];
#
#             if (!b.length) return __cmp.a;
#             else if (b[0] === 'ping') {
#                 b[2]({
#                     "gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false
#                 }, true);
#             }
#             else {
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json = event.data;
#             if (msgIsString) {
#                 try {
#                     json = JSON.parse(event.data);
#                 } catch (e) {}
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function (retValue, success) {
#                     var returnMsg = {
#                         "__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }
#                     };
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#
#         if (typeof (__cmp) !== 'function') {
#             window.__cmp = stubCMP;
#             __cmp.msgHandler = cmpMsgHandler;
#             if (window.addEventListener)
#                 window.addEventListener('message', cmpMsgHandler, false);
#             else window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#
# </script>
# <!-- End Consent Manager Tag : Stubbed -->
#
#
# <script type="text/javascript">
#     window.__cmp('init');
# </script>
# <script type="text/javascript" src="https://s.yimg.com/nb/AdLib/adlib-prod.umd.min.js"></script></head>
#
# <body id="">
#   <data data-login="false" data-login-href="https://movies.yahoo.com.tw/login"></data>
#   <span id="ad-space-id" data-id="794026770"></span>
#   <span id="pt-type" data-id="3"></span>
#   <!--Website-->
#   <div id="maincontainer">
#     <header>
#       <div id="y-header">
#     <nav class="nav content">
#         <ul>
#             <li><a class="gabtn" href="https://tw.yahoo.com/" data-ga="['頻道入口','頻道入口_Yahoo首頁','頁首_頻道入口']"><span class="icon_home"></span>首頁</a></li>
#             <li><a class="gabtn" href="https://tw.mail.yahoo.com/" data-ga="['頻道入口','頻道入口_信箱','頁首_頻道入口']">信箱</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/" data-ga="['頻道入口','頻道入口_新聞','頁首_頻道入口']">新聞</a></li>
#             <li><a class="gabtn" href="https://tw.stock.yahoo.com/" data-ga="['頻道入口','頻道入口_股市','頁首_頻道入口']">股市</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/weather-forecast/" data-ga="['頻道入口','頻道入口_氣象','頁首_頻道入口']">氣象</a></li>
#             <li><a class="gabtn" href="https://tw.sports.yahoo.com/" data-ga="['頻道入口','頻道入口_運動','頁首_頻道入口']">運動</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/entertainment" data-ga="['頻道入口','頻道入口_名人娛樂','頁首_頻道入口']">名人娛樂</a></li>
#             <li><a class="gabtn" href="http://tw.mobile.yahoo.com/" data-ga="['頻道入口','頻道入口_App下載','頁首_頻道入口']">App下載</a></li>
#             <li><a class="gabtn" href="https://tw.buy.yahoo.com/" data-ga="['頻道入口','頻道入口_購物中心','頁首_頻道入口']">購物中心</a></li>
#             <li><a class="gabtn" href="https://tw.mall.yahoo.com/" data-ga="['頻道入口','頻道入口_商域','頁首_頻道入口']">商城</a></li>
#             <li><a class="gabtn" href="https://tw.bid.yahoo.com/" data-ga="['頻道入口','頻道入口_拍賣','頁首_頻道入口']">拍賣</a></li>
#             <li class="nav_more">
#                 <a href="javascript:void(0)">更多<span class="icon_more"></span></a>
#                 <div class="dropdown_list">
#                     <dl>
#                         <dd><a class="gabtn" href="https://tw.video.yahoo.com/" data-ga="['頻道入口','頻道入口_影音','頁首_頻道入口']">影音</a></dd>
#                         <dd><a class="gabtn" href="https://autos.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_汽車機車','頁首_頻道入口']">汽車機車</a></dd>
#                         <dd><a class="gabtn" href="https://movies.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_電影','頁首_頻道入口']">電影</a></dd>
#                         <dd><a class="gabtn" href="https://tw.dictionary.yahoo.com/" data-ga="['頻道入口','頻道入口_字典','頁首_頻道入口']">字典</a></dd>
#                         <dd><a class="gabtn" href="https://games.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_遊戲','頁首_頻道入口']">遊戲</a></dd>
#                         <dd><a class="gabtn" href="https://travel.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_旅遊','頁首_頻道入口']">旅遊</a></dd>
#                         <dd><a class="gabtn" href="https://tw.money.yahoo.com/" data-ga="['頻道入口','頻道入口_理財','頁首_頻道入口']">理財</a></dd>
#                         <dd><a class="gabtn" href="https://house.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_房地產','頁首_頻道入口']">房地產</a></dd>
#                         <dd><a class="gabtn" href="https://style.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_時尚美妝','頁首_頻道入口']">時尚美妝</a></dd>
#                         <dd><a class="gabtn" href="https://tw.discount.yahoo.net/index.php?group=all" data-ga="['頻道入口','頻道入口_折扣城','頁首_頻道入口']">折扣城</a></dd>
#                     </dl>
#                 </div>
#             </li>
#         </ul>
#     </nav>
# </div>
# <div id="kv">
#     <div class="content">
#         <div id="y_hous_serch" class="_c">
#             <div id="y_serch_l">
#                 <a id="ylogo" class="gabtn" href="https://movies.yahoo.com.tw/index.html" data-ga="['電影頻道logo','電影頻道logo_連結','頁首_電影頻道logo']">
#                     <img src="/build/images/header_logo.png" srcset="/build/images/header_logo@2x.png 2x, /build/images/header_logo@3x.png 3x" alt="Yahoo Logo" />
#                 </a>
#                 <form method="get" action="https://tw.search.yahoo.com/search" target="_blank">
#                     <input id="serchinput" name="p" type="text" placeholder="搜尋"  autocomplete="off">
#                     <div class="inputex" style="visibility:hidden"></div>
#
#                     <button class="serch_movie gabtn" data-ga="['top search','top search_電影明星搜尋','']" data-input="['input','serchinput','']">電影‧明星搜尋</button><!--20170531-->
#                     <button class="gabtn" type="submit" data-ga="['top search','top search_網頁搜尋','']" data-input="['input','serchinput','']">網頁搜尋</button><!--20170531-->
#                     <input type="hidden" id="fr" name="fr" value="ush-movies">
#                 </form>
#             </div>
#
#         </div>
#     </div>
# </div>
# <!-- jurisdiction-type: WORLD -->
# <div id="bg_main_menu">
#     <div class="content">
#         <ul id="mainmenu">
#                                   <li><a href="https://movies.yahoo.com.tw/" target=""
#                                     class="gabtn" data-ga="['選單','選單_首頁','頁首_選單']">
#                   <span>首頁</span>
#               </a></li>
#                                           <li><a href="https://movies.yahoo.com.tw/movie_thisweek.html" target=""
#                                     class="gabtn" data-ga="['選單','選單_本週新片','頁首_選單']">
#                   <span>本週新片</span>
#               </a></li>
#                                           <li><a href="https://movies.yahoo.com.tw/movie_intheaters.html" target=""
#                                     class="gabtn" data-ga="['選單','選單_上映中','頁首_選單']">
#                   <span>上映中</span>
#               </a></li>
#                                           <li><a href="https://movies.yahoo.com.tw/movie_comingsoon.html" target=""
#                                     class="gabtn" data-ga="['選單','選單_即將上映','頁首_選單']">
#                   <span>即將上映</span>
#               </a></li>
#                                           <li><a href="https://movies.yahoo.com.tw/trailer_index.html" target=""
#                                     class="gabtn" data-ga="['選單','選單_預告片','頁首_選單']">
#                   <span>預告片</span>
#               </a></li>
#                                           <li><a href="https://movies.yahoo.com.tw/chart.html" target=""
#                                     class="gabtn" data-ga="['選單','選單_排行榜','頁首_選單']">
#                   <span>排行榜</span>
#               </a></li>
#                                 <li class="hassub">
#               <a href="https://movies.yahoo.com.tw/article_index.html" class="gabtn"  target=""
#                  data-ga="['選單','選單_情報站','頁首_選單']">
#                   <span>情報站</span></a>
#               <div class="submenu">
#                   <dl class="submenu_inner">
#                                             <dt><a href="https://movies.yahoo.com.tw/tagged/movieheadline"  target=""
#                              class="gabtn" data-ga="['選單','選單_情報站_電影新聞','頁首_選單']">
#                               電影新聞</a></dt>
#                                             <dt><a href="https://movies.yahoo.com.tw/tagged/spotlight"  target=""
#                              class="gabtn" data-ga="['選單','選單_情報站_專題報導','頁首_選單']">
#                               專題報導</a></dt>
#                                             <dt><a href="https://movies.yahoo.com.tw/tagged/moviereview"  target=""
#                              class="gabtn" data-ga="['選單','選單_情報站_影評','頁首_選單']">
#                               影評</a></dt>
#                                             <dt><a href="https://bit.ly/3x92T6e"  target=""
#                              class="gabtn" data-ga="['選單','選單_情報站_第93屆奧斯卡','頁首_選單']">
#                               第93屆奧斯卡</a></dt>
#                                             <dt><a href="https://bit.ly/3fQxaRo"  target=""
#                              class="gabtn" data-ga="['選單','選單_情報站_金馬奇幻影展','頁首_選單']">
#                               金馬奇幻影展</a></dt>
#                                         </dl>
#               </div>
#           </li>
#                                           <li><a href="https://movies.yahoo.com.tw/tv_index.html" target=""
#                                     class="gabtn" data-ga="['選單','選單_電視時刻','頁首_選單']">
#                   <span>電視時刻</span>
#               </a></li>
#                                 <li class="hassub">
#               <a href="https://movies.yahoo.com.tw/ott_index.html" class="gabtn"  target=""
#                  data-ga="['選單','選單_追劇咖','頁首_選單']">
#                   <span>追劇咖</span></a>
#               <div class="submenu">
#                   <dl class="submenu_inner">
#                                             <dt><a href="https://movies.yahoo.com.tw/tagged/ottdrama"  target=""
#                              class="gabtn" data-ga="['選單','選單_追劇咖_線上戲劇','頁首_選單']">
#                               線上戲劇</a></dt>
#                                             <dt><a href="https://movies.yahoo.com.tw/tagged/ottmovie"  target=""
#                              class="gabtn" data-ga="['選單','選單_追劇咖_線上電影','頁首_選單']">
#                               線上電影</a></dt>
#                                         </dl>
#               </div>
#           </li>
#                                 <li class="hassub">
#               <a href="https://bit.ly/3haYlHf" class="gabtn"  target=""
#                  data-ga="['選單','選單_玩命關頭9','頁首_選單']">
#                   <span>玩命關頭9</span></a>
#               <div class="submenu">
#                   <dl class="submenu_inner">
#                                             <dt><a href="https://bit.ly/3jYCjbT"  target=""
#                              class="gabtn" data-ga="['選單','選單_玩命關頭9_暑假必追','頁首_選單']">
#                               暑假必追</a></dt>
#                                         </dl>
#               </div>
#           </li>
#                       </ul>
#
#     </div>
# </div>
#     </header>
#     <!--主內容-->
#     <main>
#       <!--top_ad-->
#       <div class="maincontent ga_movie_intro">
#
#         <div id="boxLDRB" class="boxAD"></div>
#         <div id="top_serch" class="content _c">
#           <div data-topserch="0">
#     <div class="tab_serch _c">
#         <div class="tab_hot">
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/自殺突擊隊-集結-the-suicide-squad-11328" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門1','瑪格羅比']">瑪格羅比</a>
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/詭老-old-11409" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門2','詭老']">詭老</a>
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/比得兔兔-peter-rabbit-2-the-runaway-10488" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門3','比得兔兔']">比得兔兔</a>
#                     </div>
#         <a class="btn_booking btn_toptxt gabtn" target="_blank"
#            data-ga="['search box','search box_訂票客服中心','']"
#            href="https://www.ezding.com.tw/page/faq/faq.html">訂票客服中心</a>
#         <a class="btn_all btn_toptxt gabtn" href="https://movies.yahoo.com.tw/theater_list.html"
#            data-ga="['search box','search box_戲院總覽','']">戲院總覽</a>
#     </div>
#
#     <span id="mainURL" data-url="https://movies.yahoo.com.tw"></span>
#     <span id="searchType" data-type="0"></span>
#     <div class="tab_serchbar">
#         <div class="icon_serch"></div>
#         <select name="search_type" id="movie_time">
#             <option value="0">電影時刻</option>
#             <option value="1">電視時刻</option>
#             <option value="2">快速訂票</option>
#             <option value="3">電影/明星搜尋</option>
#         </select>
#
#         <!--tab_serchbar  style0-->
#         <div class="top_change" data-change = "0" style="">
#             <form id="form_moviearea" method="get" action="https://movies.yahoo.com.tw/movietime_result.html">
#                 <span>選擇<br>片名</span>
#                     <select id="sbox_mid" name="movie_id" class="movie_name">
#                         <option value="">請選擇片名</option>
#                                                                                     <option value="10482" data-name="玩命關頭9">玩命關頭9</option>
#                                                             <option value="11450" data-name="青春：第50屆日本全國高中棒球錦標賽">青春：第50屆日本全國高中棒球錦標賽</option>
#                                                             <option value="11449" data-name="甲子園：夢想競技場">甲子園：夢想競技場</option>
#                                                             <option value="11441" data-name="合法伴侶">合法伴侶</option>
#                                                             <option value="11425" data-name="雙面薇若妮卡 經典數位修復">雙面薇若妮卡 經典數位修復</option>
#                                                             <option value="11400" data-name="人聲">人聲</option>
#                                                             <option value="11368" data-name="薄荷糖">薄荷糖</option>
#                                                             <option value="11268" data-name="路卡的夏天">路卡的夏天</option>
#                                                             <option value="11439" data-name="驅魔禁區">驅魔禁區</option>
#                                                             <option value="11328" data-name="自殺突擊隊：集結">自殺突擊隊：集結</option>
#                                                             <option value="11438" data-name="怪奇大廈">怪奇大廈</option>
#                                                             <option value="11435" data-name="太陽出來之後">太陽出來之後</option>
#                                                             <option value="11429" data-name="理髮師的男人 經典數位修復">理髮師的男人 經典數位修復</option>
#                                                             <option value="11421" data-name="破碎的瞬間">破碎的瞬間</option>
#                                                             <option value="11420" data-name="罪之聲">罪之聲</option>
#                                                             <option value="11409" data-name="詭老">詭老</option>
#                                                             <option value="11396" data-name="淘寶少年">淘寶少年</option>
#                                                             <option value="11389" data-name="小王子公主心">小王子公主心</option>
#                                                             <option value="11364" data-name="LIP X LIP享受這世界的方法">LIP X LIP享受這世界的方法</option>
#                                                             <option value="10315" data-name="叢林奇航">叢林奇航</option>
#                                                             <option value="11428" data-name="極速引爆">極速引爆</option>
#                                                             <option value="11424" data-name="手捲煙">手捲煙</option>
#                                                             <option value="11376" data-name="厲陰宅3：是惡魔逼我的">厲陰宅3：是惡魔逼我的</option>
#                                                             <option value="11391" data-name="花束般的戀愛">花束般的戀愛</option>
#                                                             <option value="11375" data-name="貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年">貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年</option>
#                                                             <option value="11342" data-name="怪物奇兵 全新世代">怪物奇兵 全新世代</option>
#                                                             <option value="11300" data-name="野蠻糾碴隊">野蠻糾碴隊</option>
#                                                             <option value="11201" data-name="失控的審判">失控的審判</option>
#                                                             <option value="10397" data-name="黑寡婦">黑寡婦</option>
#                                                             <option value="11340" data-name="玩命鈔劫">玩命鈔劫</option>
#                                                             <option value="11311" data-name="死亡漩渦：奪魂鋸新遊戲">死亡漩渦：奪魂鋸新遊戲</option>
#                                                             <option value="11206" data-name="名偵探柯南：緋色的彈丸">名偵探柯南：緋色的彈丸</option>
#                                                             <option value="11346" data-name="一級任務">一級任務</option>
#                                                             <option value="11338" data-name="真．鮫島事件">真．鮫島事件</option>
#                                                             <option value="11073" data-name="永生戰">永生戰</option>
#                                                             <option value="11327" data-name="殺戮輪迴">殺戮輪迴</option>
#                                                             <option value="11263" data-name="私刑救援">私刑救援</option>
#                                                             <option value="11254" data-name="真人快打">真人快打</option>
#                                                             <option value="11296" data-name="誰殺了大個子">誰殺了大個子</option>
#                                                             <option value="11295" data-name="警慌失措">警慌失措</option>
#                                                             <option value="11258" data-name="南巫">南巫</option>
#                                                             <option value="11255" data-name="當男人戀愛時">當男人戀愛時</option>
#                                                             <option value="11126" data-name="無名弒">無名弒</option>
#                                                             <option value="11242" data-name="波麗萊多里鬼屋">波麗萊多里鬼屋</option>
#                                                             <option value="11171" data-name="揭大歡喜">揭大歡喜</option>
#                                                             <option value="10519" data-name="花漾女子">花漾女子</option>
#                                                             <option value="11222" data-name="東經北緯">東經北緯</option>
#                                                             <option value="11205" data-name="刺殺小說家">刺殺小說家</option>
#                                                             <option value="11160" data-name="複身犯">複身犯</option>
#                                                             <option value="11159" data-name="我沒有談的那場戀愛">我沒有談的那場戀愛</option>
#                                                             <option value="11072" data-name="湯姆貓與傑利鼠">湯姆貓與傑利鼠</option>
#                                                             <option value="11162" data-name="角頭–浪流連">角頭–浪流連</option>
#                                                             <option value="11089" data-name="靈魂急轉彎">靈魂急轉彎</option>
#                                                             <option value="10388" data-name="汪星人的奇幻漂流">汪星人的奇幻漂流</option>
#                                                                         </select>
#                 <span>選擇<br>地區</span>
#                 <select id="sbox_aid" name="area_id" class="movie_area">
#
#                 </select>
#                 <div class="btn_serch gabtn"
#                      data-ga="['search box','search box_電影時刻','']" data-input="['select','sbox_mid','sbox_aid']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style1-->
#         <div class="top_change" data-change = "1" style="display:none;">
#             <form id="form_catechannel" method="get" action="https://movies.yahoo.com.tw/tv_channels.html" style="display:inline;">
#                 <span>選擇<br>分類</span>
#                 <select id="sbox_cid" name="tv_category_id" class="movie_theater">
#                     <option value="">請選擇分類</option>
#                                                                         <option value="1" data-name="西片">西片</option>
#                                                     <option value="2" data-name="國片">國片</option>
#                                                     <option value="3" data-name="戲劇">戲劇</option>
#                                                     <option value="4" data-name="體育">體育</option>
#                                                     <option value="5" data-name="綜合">綜合</option>
#                                                     <option value="6" data-name="知性">知性</option>
#                                                     <option value="7" data-name="日本">日本</option>
#                                                     <option value="8" data-name="音樂">音樂</option>
#                                                     <option value="9" data-name="卡通">卡通</option>
#                                                     <option value="10" data-name="新聞">新聞</option>
#                                                     <option value="11" data-name="財經">財經</option>
#                                                     <option value="12" data-name="宗教">宗教</option>
#                                                             </select>
#                 <span>選擇<br>頻道</span>
#                 <select id="sbox_chid" name="channel" class="movie_name">
#                 </select>
#                 <div class="btn_serch gabtn"
#                      data-ga="['search box','search box_電視時刻','']" data-input="['select','sbox_cid','sbox_chid']">查詢</div>
#             </form>
#             <form id="form_channelname" method="get" action="https://movies.yahoo.com.tw/tvtime_result.html" style="display:inline;">
#                 <input id="sbox_cname" class="tvserch" id="tv_channel_name" name="tv_channel_name" type="text" placeholder="電視節目查詢"  autocomplete="off"
#                        onfocus="this.placeholder=''" onblur="this.placeholder='電視節目查詢'" onkeypress="chlSearchForm(event);">
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_電視節目查詢','']" data-input="['input','sbox_cname','']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style2-->
#         <div class="top_change" data-change = "2" style="display:none;">
#             <form id="form_movieticket" method="get" action="https://www.ezding.com.tw/page/booking/index.html?channel=yahoo&campaign_code=yahoopc">
#                 <span>選擇<br>戲院</span>
#                 <select id="sbox_tid" name="cinemaId" class="movie_theater">
#                     <option value="">請選擇戲院</option>
#                                                                         <option value="40288eb0050f542401050f554e7e0674">台北信義威秀影城</option>
#                                                     <option value="40288eb0050f542401050f5550201811">哈拉影城</option>
#                                                     <option value="470e99e70b5611eaa91e06ba2bcebcfa">MUVIE CINEMAS台北松仁威秀</option>
#                                                     <option value="46efa950eafa11e38b12987bdb90dba4">台北樂聲影城</option>
#                                                     <option value="40288eb0050f542401050f5681782dc5">喜樂時代影城南港店</option>
#                                                     <option value="e9c365f27f4e11e494ae8b4ddf78b93a">台北in89豪華數位影城</option>
#                                                     <option value="4c163aba9c5311e494ae8b4ddf78b93a">台北新民生戲院</option>
#                                                     <option value="40288eb0050f542401050f5566201ba4">台北華威天母影城</option>
#                                                     <option value="f644412efbb811e58858f2128151146f">台北真善美劇院</option>
#                                                     <option value="5f60dacd-45b3-102d-8d74-e400529c">台北京站威秀影城</option>
#                                                     <option value="b020ba50fbc811e58858f2128151146f">梅花數位影城</option>
#                                                     <option value="40288eb0050f542401050f55532606b5">喜滿客絕色影城</option>
#                                                     <option value="cf2b5aa8132f11e6b767a1b123456789">台北新光影城</option>
#                                                     <option value="40288eb0050f31210ada0f55676b1bbc">台北美麗華大直影城</option>
#                                                     <option value="c93fa3fb52a34755b123838886cc8599">中和環球威秀影城</option>
#                                                     <option value="737ece862a0111e18e86000bdb90dba4">板橋大遠百威秀影城</option>
#                                                     <option value="73544d843cd311e69bb83d0f96c001c2">林口MITSUI OUTLET PARK威秀影城</option>
#                                                     <option value="c072c5c43fc011e9a245782bcb259cad">喜樂時代影城永和店</option>
#                                                     <option value="5d4b59f567ac11e7a6b1061be09fe071">桃園in89統領影城</option>
#                                                     <option value="c256b670b10811e8959e782bcb259cad">桃園統領威秀影城</option>
#                                                     <option value="43e1c5fc8abc4cb7ae03d061f892d7ab">桃園新光影城</option>
#                                                     <option value="4f9fbbac7a2d11e18e86000bdb90dba4">新竹巨城威秀影城</option>
#                                                     <option value="40288eb0050f542401050f5573651ca2">新竹大遠百威秀影城</option>
#                                                     <option value="883ddebefe9e11e49e5e8d16c6a1d23a">頭份尚順威秀影城</option>
#                                                     <option value="7ff29bea908122e9060e893bcb360cad">台中豐原in89豪華影城</option>
#                                                     <option value="40288eb0050f542401050f5576601cdc">台中Tiger City威秀影城</option>
#                                                     <option value="9f1b3df8f0a44110ab9412513c546d33">台中新時代凱擘影城</option>
#                                                     <option value="84599c0a220d11e18e86000bdb90dba4">台中大遠百威秀影城</option>
#                                                     <option value="9fa318f9c99f4f6987a46efc5e3f50f2">台中新光影城</option>
#                                                     <option value="40288eb0050f542401050f557dfc1d65">台南大遠百威秀影城</option>
#                                                     <option value="370b0003943222e8a7b2172be10fe182">台南FOCUS威秀影城</option>
#                                                     <option value="c3ab0cdc8cad11e494ae8b4ddf78b93a">台南南紡威秀影城</option>
#                                                     <option value="5d4b59f597ac11e7a6b1091be09fe001">台南真善美劇院</option>
#                                                     <option value="a6f9c512bec5463183d3d7eaec37fb42">台南新光影城</option>
#                                                     <option value="40288eb0050f542401050f5582141dac">高雄大遠百威秀影城</option>
#                                                     <option value="44f76448bf2511e59a5d4b53bcb866d6">高雄in89駁二電影院</option>
#                                                     <option value="40288eb0050f542401050f5581582dc5">喜滿客夢時代影城</option>
#                                                     <option value="2c28121ae2c711e292f7000bdb90dba4">中影屏東影城</option>
#                                                     <option value="e8bf57d61edb11e9a245782bcb259cad">花蓮新天堂樂園威秀影城</option>
#                                                     <option value="6ff18bea897011e8959e782bcb259cad">澎湖in89豪華影城</option>
#                                                             </select>
#                 <span>選擇<br>片名</span>
#                 <select id="sbox_tmid" name="movieId" class="movie_name">
#
#                 </select>
#                 <span>選擇<br>日期</span>
#                 <select name="showDate" class="movie_day">
#
#                 </select>
#                 <span>選擇<br>場次</span>
#                 <select name="session" class="movie_screenings">
#
#                 </select>
#                 <span>選擇<br>數量</span>
#                 <select name="ticketQuantity" class="movie_amount">
#
#                 </select>
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_快速訂票','']"
#                      data-input="['select','sbox_tid','sbox_tmid']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style3-->
#         <div class="top_change" data-change = "3" style="display:none;">
#             <form id="form_starsearch" method="get" action="https://movies.yahoo.com.tw/moviesearch_result.html">
#                 <input id="starserch" class="starserch" type="text" name="keyword" placeholder="電影 / 明星搜尋"
#                        onfocus="this.placeholder=''" onblur="this.placeholder='電影/ 明星搜尋'" autocomplete="off">
#                 <div class="inputex" style="visibility:hidden">
#                 </div>
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_電影明星搜尋','']"
#                      data-input="['input','starserch','']">查詢</div>
#             </form>
#         </div>
#
#     </div>
# </div>
#         </div>
#                 <div id="container" class="content _c">
#           <div id="content_r">
#             <!--AD 300X250-->
# <!-- if $exist diff with 0 will removed from module section -->
# <div id="boxLREC" class="top_ad_300_250 r_box" data-ad="LREC" data-ad-hashtag="">
# </div>
# <!--AD 300X100-->
# <div id="boxNP1" class="ad_300_250 r_box" data-ad="NP1">
# </div>
# <!--電影排行榜-->
# <div class="r_box _c">
#   <div class="title">
#         <span>
#             電影排行榜
#         </span>
#   </div>
#
#   <div class="r_box_inner">
#     <ul class="tabbox_btn_r">
#       <li data-id="list1" class="select">台北票房榜</li>
#       <li data-id="list2">全美票房榜</li>
#       <li data-id="list3">預告片榜</li>
#     </ul>
#     <div class="ranking_inner_r">
#       <div class="tab-content">
#         <div id="list1" class="tab-pane">
#           <div class="ranking_top_info_r _c">
#                         <div class="ranking_top_info_img_r">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%87%AA%E6%AE%BA%E7%AA%81%E6%93%8A%E9%9A%8A-%E9%9B%86%E7%B5%90-the-suicide-squad-11328"
#                  class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','自殺突擊隊：集結']"><img
#                   src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/July2021/wBcP1IO87kVxofoKeK4U-1024x1462.jpg" alt=""></a>
#             </div>
#             <div class="ranking_top_info_inner_r">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%87%AA%E6%AE%BA%E7%AA%81%E6%93%8A%E9%9A%8A-%E9%9B%86%E7%B5%90-the-suicide-squad-11328"
#                      class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','自殺突擊隊：集結']">
#                   自殺突擊隊：集結</a>
#               <span class="text_truncate_4 text_truncate_dot"><p>歡迎來到地獄&mdash;全美死亡率最高的「美夢監獄」。那裡關押著最兇惡的超級反派，他們為了逃離該處願意付出任何代價，甚至不惜加入超級神祕又黑幕重重的X特遣隊。這次九死一生的任務是什麼呢？首先結集「血腥運動」、「和平使者」、「迴旋鏢隊長」、「捕鼠人2」、「智者」、「鯊魚王」、「黑色守衛」、「標槍」，以及大家最喜歡的精神病患「哈莉奎茵」等一幫罪犯，給他們配上最精良的重裝武器，再把他們扔&hellip;請注意真的是用扔的，到與世隔絕又布滿敵軍的柯多瑪堤小島。他們徒步穿越每個角落都藏滿敵對兵力和武裝傭兵的叢林，突擊隊員在瑞克佛萊格上校一人隨行並帶領管束下，執行著搜索及摧毀的任務&hellip;</p>
# <p>&nbsp;</p>
# <p>阿曼達華勒的政府技工則從耳機裡提點監控，全程緊迫盯人。與往常一樣，他們只要踏錯一步就會屍骨無存（無論是死於敵方的手下、自己隊友的暗算，或是華勒的親自下令）。若真要下注賭個輸贏，明智的選擇絕對是押他們落敗，全軍覆沒。</p></span>
#             </div>
#                       </div>
#           <ul class="ranking_list_r">
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%87%AA%E6%AE%BA%E7%AA%81%E6%93%8A%E9%9A%8A-%E9%9B%86%E7%B5%90-the-suicide-squad-11328"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','自殺突擊隊：集結']">
#                   <li class="select">
#                     <div class="num">1</div>
#                     <span>自殺突擊隊：集結</span>
#                   </li>
#                 </a>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%BB%91%E5%AF%A1%E5%A9%A6-black-widow-10397"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','黑寡婦']">
#                   <li class="">
#                     <div class="num">2</div>
#                     <span>黑寡婦</span>
#                   </li>
#                 </a>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8F%A2%E6%9E%97%E5%A5%87%E8%88%AA-jungle-cruise-10315"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','叢林奇航']">
#                   <li class="">
#                     <div class="num">3</div>
#                     <span>叢林奇航</span>
#                   </li>
#                 </a>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%B7%AF%E5%8D%A1%E7%9A%84%E5%A4%8F%E5%A4%A9-luca-11268"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','路卡的夏天']">
#                   <li class="">
#                     <div class="num">4</div>
#                     <span>路卡的夏天</span>
#                   </li>
#                 </a>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8E%B2%E9%99%B0%E5%AE%853-%E6%98%AF%E6%83%A1%E9%AD%94%E9%80%BC%E6%88%91%E7%9A%84-the-conjuring-the-devil-made-me-do-it-11376"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','厲陰宅3：是惡魔逼我的']">
#                   <li class="">
#                     <div class="num">5</div>
#                     <span>厲陰宅3：是惡魔逼我的</span>
#                   </li>
#                 </a>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%AD%E8%80%81-old-11409"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','詭老']">
#                   <li class="">
#                     <div class="num">6</div>
#                     <span>詭老</span>
#                   </li>
#                 </a>
#
#                                           <li class=" unclick">
#                   <div class="num">7</div>
#                   <span>BLACKPINK THE MOVIE</span>
#                 </li>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%96%84%E8%8D%B7%E7%B3%96-peppermint-candy-11368"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','薄荷糖《4K 數位修復》']">
#                   <li class="">
#                     <div class="num">8</div>
#                     <span>薄荷糖《4K 數位修復》</span>
#                   </li>
#                 </a>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%A9%85%E9%AD%94%E7%A6%81%E5%8D%80-demonic-11439"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','驅魔禁區']">
#                   <li class="">
#                     <div class="num">9</div>
#                     <span>驅魔禁區</span>
#                   </li>
#                 </a>
#
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E4%BA%BA%E8%81%B2-the-human-voice-11400"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','人聲']">
#                   <li class="">
#                     <div class="num">10</div>
#                     <span>人聲</span>
#                   </li>
#                 </a>
#
#                       </ul>
#           <div class="rankin_time_r">統計時間 : 2021-08-07~2021-08-08</div>
#         </div>
#
#         <div id="list2" class="tab-pane">
#           <div class="ranking_top_info_r _c">
#                         <div class="ranking_top_info_img_r">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%87%AA%E6%AE%BA%E7%AA%81%E6%93%8A%E9%9A%8A-%E9%9B%86%E7%B5%90-the-suicide-squad-11328"
#                  class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','自殺突擊隊：集結']">
#                 <img src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/July2021/wBcP1IO87kVxofoKeK4U-1024x1462.jpg" alt=""></a>
#             </div>
#             <div class="ranking_top_info_inner_r">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%87%AA%E6%AE%BA%E7%AA%81%E6%93%8A%E9%9A%8A-%E9%9B%86%E7%B5%90-the-suicide-squad-11328"
#                      class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','自殺突擊隊：集結']">
#                   自殺突擊隊：集結</a>
#               <span class="text_truncate_4 text_truncate_dot"><p>歡迎來到地獄&mdash;全美死亡率最高的「美夢監獄」。那裡關押著最兇惡的超級反派，他們為了逃離該處願意付出任何代價，甚至不惜加入超級神祕又黑幕重重的X特遣隊。這次九死一生的任務是什麼呢？首先結集「血腥運動」、「和平使者」、「迴旋鏢隊長」、「捕鼠人2」、「智者」、「鯊魚王」、「黑色守衛」、「標槍」，以及大家最喜歡的精神病患「哈莉奎茵」等一幫罪犯，給他們配上最精良的重裝武器，再把他們扔&hellip;請注意真的是用扔的，到與世隔絕又布滿敵軍的柯多瑪堤小島。他們徒步穿越每個角落都藏滿敵對兵力和武裝傭兵的叢林，突擊隊員在瑞克佛萊格上校一人隨行並帶領管束下，執行著搜索及摧毀的任務&hellip;</p>
# <p>&nbsp;</p>
# <p>阿曼達華勒的政府技工則從耳機裡提點監控，全程緊迫盯人。與往常一樣，他們只要踏錯一步就會屍骨無存（無論是死於敵方的手下、自己隊友的暗算，或是華勒的親自下令）。若真要下注賭個輸贏，明智的選擇絕對是押他們落敗，全軍覆沒。</p></span>
#             </div>
#                       </div>
#           <ul class="ranking_list_r">
#                                           <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%87%AA%E6%AE%BA%E7%AA%81%E6%93%8A%E9%9A%8A-%E9%9B%86%E7%B5%90-the-suicide-squad-11328"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','自殺突擊隊：集結']">
#                   <li class="select">
#                     <div class="num">1</div>
#                     <span>自殺突擊隊：集結</span>
#                   </li>
#                 </a>
#                                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8F%A2%E6%9E%97%E5%A5%87%E8%88%AA-jungle-cruise-10315"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','叢林奇航']">
#                   <li class="">
#                     <div class="num">2</div>
#                     <span>叢林奇航</span>
#                   </li>
#                 </a>
#                                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%AD%E8%80%81-old-11409"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','詭老']">
#                   <li class="">
#                     <div class="num">3</div>
#                     <span>詭老</span>
#                   </li>
#                 </a>
#                                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%BB%91%E5%AF%A1%E5%A9%A6-black-widow-10397"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','黑寡婦']">
#                   <li class="">
#                     <div class="num">4</div>
#                     <span>黑寡婦</span>
#                   </li>
#                 </a>
#                                                         <li class=" unclick">
#                   <div class="num">5</div>
#                   <span>Stillwater</span>
#                 </li>
#                                                         <li class=" unclick">
#                   <div class="num">6</div>
#                   <span>The Green Knight</span>
#                 </li>
#                                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%80%AA%E7%89%A9%E5%A5%87%E5%85%B5-%E5%85%A8%E6%96%B0%E4%B8%96%E4%BB%A3-space-jam-a-new-legacy-11342"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','怪物奇兵 全新世代']">
#                   <li class="">
#                     <div class="num">7</div>
#                     <span>怪物奇兵 全新世代</span>
#                   </li>
#                 </a>
#                                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%89%B9%E7%A8%AE%E9%83%A8%E9%9A%8A-%E8%9B%87%E7%9C%BC%E4%B9%8B%E6%88%B0-snake-eyes-10461"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','特種部隊：蛇眼之戰']">
#                   <li class="">
#                     <div class="num">8</div>
#                     <span>特種部隊：蛇眼之戰</span>
#                   </li>
#                 </a>
#                                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%AF%86%E5%BC%92%E9%81%8A%E6%88%B22-%E5%8B%9D%E8%80%85%E5%8D%B1%E4%BA%A1-escape-room-tournament-of-champions-11408"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','密弒遊戲2：勝者危亡']">
#                   <li class="">
#                     <div class="num">9</div>
#                     <span>密弒遊戲2：勝者危亡</span>
#                   </li>
#                 </a>
#                                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%8E%A9%E5%91%BD%E9%97%9C%E9%A0%AD9-fast-furious-9-10482"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','玩命關頭9']">
#                   <li class="">
#                     <div class="num">10</div>
#                     <span>玩命關頭9</span>
#                   </li>
#                 </a>
#                                     </ul>
#           <div class="rankin_time_r">統計時間 : 2021-08-06~2021-08-08</div>
#         </div>
#
#         <div id="list3" class="tab-pane">
#           <div class="ranking_top_info_r _c">
#                           <div class="ranking_top_info_img_r">
#                 <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%8E%A9%E5%91%BD%E9%97%9C%E9%A0%AD9-fast-furious-9-10482"
#                    class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','玩命關頭9']"><img
#                     src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/July2021/tDAKOcY2jZvGxxZI3gcp-1024x1463.jpg" alt=""></a>
#               </div>
#               <div class="ranking_top_info_inner_r">
#                 <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%8E%A9%E5%91%BD%E9%97%9C%E9%A0%AD9-fast-furious-9-10482"
#                        class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','玩命關頭9']">
#                     玩命關頭9</a>
#
#                 <span class="text_truncate_4 text_truncate_dot"><p>馮迪索飾演的唐老大和莉蒂與他的兒子小布萊恩，正在過著與世隔絕的平靜生活，但是他們都知道這種平靜的生活隨時隨地都會受到致命危機的威脅。這次，這個威脅將逼迫唐老大面對他過去犯下的罪孽，如果他想要拯救他最愛的人們。他的團隊將再度攜手合作，槓上他們遇過最高竿的職業刺客和飆速車手，並且阻止他摧毀全世界的邪惡計畫。這個神秘人物也正好是早就被唐老大切斷兄弟關係的親弟弟雅各（約翰希南 飾）。</p>
# <p>&nbsp;</p>
# <p>【關於電影】</p>
# <p>曾經執導《玩命關頭》第3集、第4集、第5集和第6集的華裔導演林詣彬回歸執導《玩命關頭9》，他讓這個電影系列成為全球大賣的超級動作鉅片。《玩命關頭9》這部全新系列電影中的動作場面橫跨全球，從倫敦到東京，從中美洲到愛丁堡，然後從位於亞塞拜然的秘密地下碉堡，一直到喬治亞共和國首都提比里斯車水馬龍、熙來攘往的街頭。這一路上，老朋友將起死回生，昔日的敵人將再度回歸，歷史將被重新改寫，而且家庭真正的意義也將受到前所未有的考驗。再度回歸參與這部電影演出的堅強卡司包括蜜雪兒羅卓奎茲、泰瑞斯吉布森、路達克里斯、喬丹娜布魯斯特、娜塔莉艾曼紐、姜成鎬，以及奧斯卡影后海倫米蘭與莎莉賽隆。曾經榮獲葛萊美獎肯定的當紅歌手和超級巨星卡蒂B在《玩命關頭9》一片中將飾演全新角色蕾莎，一個和唐老大的過去有關聯的女子，另外，雷鬼動音樂巨星歐蘇納也在這部電影中客串演出。</p></span>
#               </div>
#                       </div>
#           <ul class="ranking_list_r">
#                                       <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%8E%A9%E5%91%BD%E9%97%9C%E9%A0%AD9-fast-furious-9-10482"
#                  class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','玩命關頭9']">
#                 <li class="select">
#                   <div class="num">1</div>
#                   <span>玩命關頭9</span></li>
#               </a>
#                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%99%A4%E7%95%8CII-a-quiet-place-part-ii-10435"
#                  class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','噤界II']">
#                 <li class="">
#                   <div class="num">2</div>
#                   <span>噤界II</span></li>
#               </a>
#                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8F%A2%E6%9E%97%E5%A5%87%E8%88%AA-jungle-cruise-10315"
#                  class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','叢林奇航']">
#                 <li class="">
#                   <div class="num">3</div>
#                   <span>叢林奇航</span></li>
#               </a>
#                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%AD%E8%80%81-old-11409"
#                  class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','詭老']">
#                 <li class="">
#                   <div class="num">4</div>
#                   <span>詭老</span></li>
#               </a>
#                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%B7%AF%E5%8D%A1%E7%9A%84%E5%A4%8F%E5%A4%A9-luca-11268"
#                  class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','路卡的夏天']">
#                 <li class="">
#                   <div class="num">5</div>
#                   <span>路卡的夏天</span></li>
#               </a>
#                                         <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%87%AA%E6%AE%BA%E7%AA%81%E6%93%8A%E9%9A%8A-%E9%9B%86%E7%B5%90-the-suicide-squad-11328"
# ...
#             <div class="see_more_reply" data-href="">顯示更多內容</div>
#           </div>
#           <input type="hidden" name="score" value="5">
#           <input type="hidden" name="good" value="0">
#           <input type="hidden" name="bad" value="0">
#           <input type="hidden" name="act">
#           <input type="hidden" name="review_id" value="117375065289445478">
#         </form>
#               </div>
#     </li>
#           <li>
#       <div class="usercom_inner _c">
#         <form id="form_good1" class="form_good" method="post" action="https://movies.yahoo.com.tw/ajax/thumb_review">
#           <input type="hidden" name="_token" value="xPr3gLhWaZeyoetNTpnEV1ZP090IJVUTGeG4twU8">
#           <div class="user_star _c">
#             <p>網友評分：</p>
#             <div class="starbox">
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#             </div>
#             <div class="user_num good submit_able gabtn" data-ga="['電影介紹', '電影介紹_網友短評_讚', '']">
#               <svg class="good"  width="14" height="14" viewBox="0 0 24 24"  style=" stroke-width: 0;"><path d="M2.447 21.74l-.022-10.07s1.387-.006 2.15-.006c1.094 0 1.744-.747 2.134-1.14.707-.708 1.512-1.363 2.22-2.108.187-.197.368-.395.543-.592 1.603-1.8 2.33-3.418 2.225-5.523 0-.035.053-.07.317-.03.526.085.995.584 1.13 1.58.326 2.392-.2 4.276-.723 4.678-.876.676-.36 2.002.776 2l7.12-.014c.655 0 1.257.402 1.258.764 0 .345-.528.77-.67.77h-.01c-1.56.01-1.59 2.102-.127 2.234.048.09.085.233.085.385 0 .13-.04.175-.282.256-.236.078-.505.11-.668.107h.01c-1.335-.023-1.724 1.686-.494 2.17.04.016.16.083.284.193.183.166.28.346.28.582 0 .062-.074.142-.332.26-.247.113-.516.177-.654.195-1.3.175-1.414 1.886-.147 2.21-.018-.007.038.02.1.07.11.088.175.214.175.464 0 .413-.198.553-.622.553m1.81-13.474l-5.094.01c.417-1.255.576-2.895.33-4.7-.265-1.944-1.505-3.265-3.128-3.52-1.67-.265-3.226.744-3.144 2.364.075 1.472-.422 2.57-1.67 3.975-.158.178-.324.357-.492.535-.65.686-1.352 1.342-2.052 1.948-.263.227-.47.397-.644.54l-3.21.007C.54 9.412 0 9.92 0 10.545l.025 12.327c0 .625.544 1.13 1.214 1.128 0 0 16.957-.01 17.27-.013 1.632-.002 3.043-.99 3.04-2.82 0-.457-.097-.87-.27-1.233.685-.463 1.132-1.108 1.13-1.966 0-.46-.11-.88-.293-1.256.714-.44 1.166-1.125 1.164-2.05 0-.45-.096-.882-.274-1.27.584-.547.995-1.294.994-2.12-.003-1.8-1.833-3.022-3.688-3.02z"></path></svg>
#               <span class="user_num_num"></span>
#             </div>
#             <div class="user_num bad submit_able gabtn" data-ga="['電影介紹', '電影介紹_網友短評_噓', '']">
#               <svg  class="bad"  width="14" height="14" viewBox="0 0 24 24" style="stroke-width: 0;"><path d="M21.553 2.26l.022 10.07s-1.387.006-2.15.006c-1.094 0-1.744.747-2.134 1.14-.707.708-1.512 1.363-2.22 2.108-.187.197-.368.395-.543.592-1.603 1.8-2.33 3.418-2.225 5.523 0 .035-.053.07-.317.03-.526-.085-.995-.584-1.13-1.58-.326-2.392.2-4.276.723-4.678.876-.676.36-2.002-.776-2l-7.12.014c-.655 0-1.257-.402-1.258-.764 0-.345.528-.77.67-.77h.01c1.56-.01 1.59-2.102.127-2.234-.048-.09-.085-.233-.085-.385 0-.13.04-.175.282-.256.236-.078.505-.11.668-.107h-.01c1.335.023 1.724-1.686.494-2.17-.04-.016-.16-.083-.284-.193-.183-.166-.28-.346-.28-.582 0-.062.074-.142.332-.26.247-.113.516-.177.654-.195 1.3-.175 1.414-1.886.147-2.21.018.007-.038-.02-.1-.07-.11-.088-.175-.214-.175-.464 0-.413.198-.553.622-.553M0 12.728c.003 1.8 1.833 3.022 3.688 3.02l5.093-.01c-.417 1.254-.576 2.894-.33 4.7.265 1.943 1.505 3.264 3.128 3.52 1.67.264 3.226-.745 3.144-2.365-.075-1.472.422-2.57 1.67-3.975.158-.178.324-.357.492-.535.65-.686 1.352-1.342 2.052-1.948.263-.227.47-.397.644-.54l3.21-.007c.67 0 1.21-.508 1.21-1.133l-.025-12.327c0-.625-.544-1.13-1.214-1.128 0 0-16.957.01-17.27.013-1.632.002-3.043.99-3.04 2.82 0 .457.097.87.27 1.233-.685.463-1.132 1.108-1.13 1.966 0 .46.11.88.293 1.256C1.17 7.728.717 8.413.72 9.338c0 .45.096.882.274 1.27C.41 11.154 0 11.9 0 12.727"></path></svg>
#               <span class="user_num_num"></span>
#             </div>
#             <div class="leave_reply"><i class="fa fa-reply" aria-hidden="true"></i>回應評論</div>
#                           <a class="btn_report" href="">檢舉</a>
#                       </div>
#           <span>很久以前的片子了 還是很好看 沒有主流商業片的爆點 可是Johnny在這部劇情片中演的很好喔 結局看到我都落淚了......</span>
#           <div class="user_id unuser">發表人：Twinkle</div>
#           <div class="user_time unuser">發表時間：2015-02-03 15:36:16</div>
#           <div class="check_reply unuser" data-href="https://movies.yahoo.com.tw/ajax/review_reply/117586171521978464">顯示回應(0)</div>
#           <div class="reply_wrapper">
#             <div class="see_more_reply" data-href="">顯示更多內容</div>
#           </div>
#           <input type="hidden" name="score" value="4">
#           <input type="hidden" name="good" value="2">
#           <input type="hidden" name="bad" value="0">
#           <input type="hidden" name="act">
#           <input type="hidden" name="review_id" value="117586171521978464">
#         </form>
#               </div>
#     </li>
#           <li>
#       <div class="usercom_inner _c">
#         <form id="form_good1" class="form_good" method="post" action="https://movies.yahoo.com.tw/ajax/thumb_review">
#           <input type="hidden" name="_token" value="xPr3gLhWaZeyoetNTpnEV1ZP090IJVUTGeG4twU8">
#           <div class="user_star _c">
#             <p>網友評分：</p>
#             <div class="starbox">
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#               <div class="star">
#                 <div class="starovr"></div>
#               </div>
#             </div>
#             <div class="user_num good submit_able gabtn" data-ga="['電影介紹', '電影介紹_網友短評_讚', '']">
#               <svg class="good"  width="14" height="14" viewBox="0 0 24 24"  style=" stroke-width: 0;"><path d="M2.447 21.74l-.022-10.07s1.387-.006 2.15-.006c1.094 0 1.744-.747 2.134-1.14.707-.708 1.512-1.363 2.22-2.108.187-.197.368-.395.543-.592 1.603-1.8 2.33-3.418 2.225-5.523 0-.035.053-.07.317-.03.526.085.995.584 1.13 1.58.326 2.392-.2 4.276-.723 4.678-.876.676-.36 2.002.776 2l7.12-.014c.655 0 1.257.402 1.258.764 0 .345-.528.77-.67.77h-.01c-1.56.01-1.59 2.102-.127 2.234.048.09.085.233.085.385 0 .13-.04.175-.282.256-.236.078-.505.11-.668.107h.01c-1.335-.023-1.724 1.686-.494 2.17.04.016.16.083.284.193.183.166.28.346.28.582 0 .062-.074.142-.332.26-.247.113-.516.177-.654.195-1.3.175-1.414 1.886-.147 2.21-.018-.007.038.02.1.07.11.088.175.214.175.464 0 .413-.198.553-.622.553m1.81-13.474l-5.094.01c.417-1.255.576-2.895.33-4.7-.265-1.944-1.505-3.265-3.128-3.52-1.67-.265-3.226.744-3.144 2.364.075 1.472-.422 2.57-1.67 3.975-.158.178-.324.357-.492.535-.65.686-1.352 1.342-2.052 1.948-.263.227-.47.397-.644.54l-3.21.007C.54 9.412 0 9.92 0 10.545l.025 12.327c0 .625.544 1.13 1.214 1.128 0 0 16.957-.01 17.27-.013 1.632-.002 3.043-.99 3.04-2.82 0-.457-.097-.87-.27-1.233.685-.463 1.132-1.108 1.13-1.966 0-.46-.11-.88-.293-1.256.714-.44 1.166-1.125 1.164-2.05 0-.45-.096-.882-.274-1.27.584-.547.995-1.294.994-2.12-.003-1.8-1.833-3.022-3.688-3.02z"></path></svg>
#               <span class="user_num_num"></span>
#             </div>
#             <div class="user_num bad submit_able gabtn" data-ga="['電影介紹', '電影介紹_網友短評_噓', '']">
#               <svg  class="bad"  width="14" height="14" viewBox="0 0 24 24" style="stroke-width: 0;"><path d="M21.553 2.26l.022 10.07s-1.387.006-2.15.006c-1.094 0-1.744.747-2.134 1.14-.707.708-1.512 1.363-2.22 2.108-.187.197-.368.395-.543.592-1.603 1.8-2.33 3.418-2.225 5.523 0 .035-.053.07-.317.03-.526-.085-.995-.584-1.13-1.58-.326-2.392.2-4.276.723-4.678.876-.676.36-2.002-.776-2l-7.12.014c-.655 0-1.257-.402-1.258-.764 0-.345.528-.77.67-.77h.01c1.56-.01 1.59-2.102.127-2.234-.048-.09-.085-.233-.085-.385 0-.13.04-.175.282-.256.236-.078.505-.11.668-.107h-.01c1.335.023 1.724-1.686.494-2.17-.04-.016-.16-.083-.284-.193-.183-.166-.28-.346-.28-.582 0-.062.074-.142.332-.26.247-.113.516-.177.654-.195 1.3-.175 1.414-1.886.147-2.21.018.007-.038-.02-.1-.07-.11-.088-.175-.214-.175-.464 0-.413.198-.553.622-.553M0 12.728c.003 1.8 1.833 3.022 3.688 3.02l5.093-.01c-.417 1.254-.576 2.894-.33 4.7.265 1.943 1.505 3.264 3.128 3.52 1.67.264 3.226-.745 3.144-2.365-.075-1.472.422-2.57 1.67-3.975.158-.178.324-.357.492-.535.65-.686 1.352-1.342 2.052-1.948.263-.227.47-.397.644-.54l3.21-.007c.67 0 1.21-.508 1.21-1.133l-.025-12.327c0-.625-.544-1.13-1.214-1.128 0 0-16.957.01-17.27.013-1.632.002-3.043.99-3.04 2.82 0 .457.097.87.27 1.233-.685.463-1.132 1.108-1.13 1.966 0 .46.11.88.293 1.256C1.17 7.728.717 8.413.72 9.338c0 .45.096.882.274 1.27C.41 11.154 0 11.9 0 12.727"></path></svg>
#               <span class="user_num_num"></span>
#             </div>
#             <div class="leave_reply"><i class="fa fa-reply" aria-hidden="true"></i>回應評論</div>
#                           <a class="btn_report" href="">檢舉</a>
#                       </div>
#           <span>難得強尼戴普從年輕演到老</span>
#           <div class="user_id unuser">發表人：Meek</div>
#           <div class="user_time unuser">發表時間：2015-02-03 15:36:16</div>
#           <div class="check_reply " data-href="https://movies.yahoo.com.tw/ajax/review_reply/117304696545267799">顯示回應(1)</div>
#           <div class="reply_wrapper">
#             <div class="see_more_reply" data-href="">顯示更多內容</div>
#           </div>
#           <input type="hidden" name="score" value="5">
#           <input type="hidden" name="good" value="1">
#           <input type="hidden" name="bad" value="1">
#           <input type="hidden" name="act">
#           <input type="hidden" name="review_id" value="117304696545267799">
#         </form>
#               </div>
#     </li>
#           </ul>
#         <div class="btn_plus_more usercom_more gabtn" data-ga="['電影介紹','電影介紹_網友短評_看更多','']">
#           <a href="https://movies.yahoo.com.tw/movieinfo_review.html/id=1">
#             <div class="plus"></div>
#             看更多
#             <span class="usercom" data-num='3'></span>
#           </a>
#         </div>
#       </div>
#     </div>
#
#     <!--20170616 ▽-->
# <div class="report_lb">
#   <div class="lbcontennt_bg">
#     <div class="report_inner _c">
#       <!--20170619 james add form START-->
#       <form id="lb_form" method="post" action="https://movies.yahoo.com.tw/complaint_review">
#         <input type="hidden" name="_token" value="xPr3gLhWaZeyoetNTpnEV1ZP090IJVUTGeG4twU8">
#         <ul>
#           <li><input type="radio" name="reason_type" value="1">與本電影無關、捏造假冒、不實敘述</li>
#           <li><input type="radio" name="reason_type" value="2">具有廣告性質或大量重複散布</li>
#           <li><input type="radio" name="reason_type" value="3">相互惡意攻訐、猥褻騷擾、人身攻擊</li>
#           <li><input type="radio" name="reason_type" value="4">侵犯隱私權、違反智慧財產權、涉及違法情事</li>
#           <li><input type="radio" name="reason_type" value="5">違背善良風俗</li>
#         </ul>
#         <div class="btn_report_lb">確認送出</div>
#         <div class="close_btn"><img src="/build/images/close.png" alt=""></div>
#         <input type="hidden" name="review_id">
#       </form>
#       <!--20170619 james add form END-->
#     </div>
#   </div>
# </div>
# <!--20170616 △-->    <!--原聲帶-->
#
#           </div>
#         </div>
#       </div>
#     </main>
#     <footer id="footer" class="clearfix" style="display: block;">
#       <div id="loadbox">
#   <a class="gabtn" href="https://tw.help.yahoo.com/kb/helpcentral" target="_blank"
#      data-ga="['其他連結','其他連結_服務中心','頁尾_其他連結']">服務中心</a> | <a class="gabtn"
#                                                             href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm"
#                                                             target="_blank"
#                                                             data-ga="['其他連結','其他連結_隱私權','頁尾_其他連結']">隱私權(更新)</a> | <a
#     class="gabtn" href="https://yahoo.uservoice.com/forums/600523" target="_blank"
#     data-ga="['其他連結','其他連結_建議','頁尾_其他連結']">建議</a> | <a class="gabtn"
#                                                        href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/adinfo/"
#                                                        target="_blank" data-ga="['其他連結','其他連結_關於我們的廣告','頁尾_其他連結']">關於我們的廣告</a>
#   | <a class="gabtn" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/" target="_blank"
#        data-ga="['其他連結','其他連結_服務條款','頁尾_其他連結']">服務條款(更新)</a>
#   | <a href="" target="_blank">
#
#           </a>
#   由Yahoo奇摩電影 提供
# </div>    </footer>
#   </div>
#
# <!-- Javascript -->
#   <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId            : 501887343352051,
#             autoLogAppEvents : true,
#             xfbml            : true,
#             version          : 'v2.9'
#         });
#         FB.AppEvents.logPageView();
#     };
#
#     (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#
#     function fbShareSend() {
#         var shareSendAll = document.querySelectorAll('.fb_share_send');
#         for(var i = 0; i < shareSendAll.length; i++) {
#             shareSendAll[i].onclick = function() {
#                 FB.ui({
#                     method: 'share_open_graph',
#                     action_type: 'og.likes',
#                     action_properties: JSON.stringify({
#                         object: this.getAttribute('data-href') ? this.getAttribute('data-href') : 'https://movies.yahoo.com.tw/movieinfo_main/1',
#                     })
#                 }, function(response){});
#             }
#         }
#     }
#
#     fbShareSend();
# </script>
# <script src="https://s.yimg.com/ss/rapid3.js"></script>
# <script src="https://s.yimg.com/ss/rapidworker-1.2.js"></script>
#
# <!-- Native Ad -->
# <script type="text/javascript">
#   const nativeAdAll = "bdd2eb9c-51e8-404a-921c-ae7090fc5fda";
#   const nativeAdOption = "";
#
#   window.native = window.native || [];
#   window.native.push(nativeAdAll);
#   if(nativeAdOption.length) {
#     window.native.push(nativeAdOption);
#   }
#   window.apiKey = "QS4CB5BPWQKCYKVVSR89";
#
#   (function(d) {
#     var script = d.createElement("script");
#     script.async = true;
#     script.src = "https://s.yimg.com/dy/ads/native.js";
#     d.body.appendChild(script);
#   })(document);
# </script>
#
# <script type="text/javascript" src="/build/js/app.js?id=d61aea100caae4b99b62&amp;r=1614354020"></script>
# <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&c2=7241469&c7=https%3A%2F%2Fmovies.yahoo.com.tw%2Fmovieinfo_main%2F1&c5=794026770&cv=2.0&cj=1" width="1" height="1" alt=""/></noscript>
# <script>
#
#
#
#   </script>
#
# <script type="application/javascript">
#   (function (w, d, t, r, u) {
#     w[u] = w[u] || []
#     w[u].push({
#       'projectId': '10000',
#       'properties': {
#         'pixelId': '428726',
#         'qstrings': {'country': 'tw', 'property': 'movie', 'tag': ''}
#       }
#     })
#     var s = d.createElement(t)
#     s.src = r
#     s.async = true
#     s.onload = s.onreadystatechange = function () {
#       var y, rs = this.readyState, c = w[u]
#       if (rs && rs != 'complete' && rs != 'loaded') {return}
#       try {
#         y = YAHOO.ywa.I13N.fireBeacon
#         w[u] = []
#         w[u].push = function (p) {y([p])}
#         y(c)
#       } catch (e) {}
#     }
#     var scr = d.getElementsByTagName(t)[0], par = scr.parentNode
#     par.insertBefore(s, scr)
#   })(window, document, 'script', 'https://s.yimg.com/wi/ytc.js', 'dotq')
# </script>
# </body>
# </html>

# %%
soup = BeautifulSoup(resp.text, 'lxml')
movie_html = soup.find("select", attrs={'name':'movie_id'})
print(movie_html)
# Out:
# <select class="movie_name" id="sbox_mid" name="movie_id">
# <option value="">請選擇片名</option>
# <option data-name="玩命關頭9" value="10482">玩命關頭9</option>
# <option data-name="青春：第50屆日本全國高中棒球錦標賽" value="11450">青春：第50屆日本全國高中棒球錦標賽</option>
# <option data-name="甲子園：夢想競技場" value="11449">甲子園：夢想競技場</option>
# <option data-name="合法伴侶" value="11441">合法伴侶</option>
# <option data-name="雙面薇若妮卡 經典數位修復" value="11425">雙面薇若妮卡 經典數位修復</option>
# <option data-name="人聲" value="11400">人聲</option>
# <option data-name="薄荷糖" value="11368">薄荷糖</option>
# <option data-name="路卡的夏天" value="11268">路卡的夏天</option>
# <option data-name="驅魔禁區" value="11439">驅魔禁區</option>
# <option data-name="自殺突擊隊：集結" value="11328">自殺突擊隊：集結</option>
# <option data-name="怪奇大廈" value="11438">怪奇大廈</option>
# <option data-name="太陽出來之後" value="11435">太陽出來之後</option>
# <option data-name="理髮師的男人 經典數位修復" value="11429">理髮師的男人 經典數位修復</option>
# <option data-name="破碎的瞬間" value="11421">破碎的瞬間</option>
# <option data-name="罪之聲" value="11420">罪之聲</option>
# <option data-name="詭老" value="11409">詭老</option>
# <option data-name="淘寶少年" value="11396">淘寶少年</option>
# <option data-name="小王子公主心" value="11389">小王子公主心</option>
# <option data-name="LIP X LIP享受這世界的方法" value="11364">LIP X LIP享受這世界的方法</option>
# <option data-name="叢林奇航" value="10315">叢林奇航</option>
# <option data-name="極速引爆" value="11428">極速引爆</option>
# <option data-name="手捲煙" value="11424">手捲煙</option>
# <option data-name="群青戰記" value="11397">群青戰記</option>
# <option data-name="厲陰宅3：是惡魔逼我的" value="11376">厲陰宅3：是惡魔逼我的</option>
# <option data-name="花束般的戀愛" value="11391">花束般的戀愛</option>
# <option data-name="貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年" value="11375">貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年</option>
# <option data-name="怪物奇兵 全新世代" value="11342">怪物奇兵 全新世代</option>
# <option data-name="野蠻糾碴隊" value="11300">野蠻糾碴隊</option>
# <option data-name="失控的審判" value="11201">失控的審判</option>
# <option data-name="黑寡婦" value="10397">黑寡婦</option>
# <option data-name="玩命鈔劫" value="11340">玩命鈔劫</option>
# <option data-name="死亡漩渦：奪魂鋸新遊戲" value="11311">死亡漩渦：奪魂鋸新遊戲</option>
# <option data-name="名偵探柯南：緋色的彈丸" value="11206">名偵探柯南：緋色的彈丸</option>
# <option data-name="一級任務" value="11346">一級任務</option>
# <option data-name="真．鮫島事件" value="11338">真．鮫島事件</option>
# <option data-name="永生戰" value="11073">永生戰</option>
# <option data-name="殺戮輪迴" value="11327">殺戮輪迴</option>
# <option data-name="私刑救援" value="11263">私刑救援</option>
# <option data-name="真人快打" value="11254">真人快打</option>
# <option data-name="誰殺了大個子" value="11296">誰殺了大個子</option>
# <option data-name="警慌失措" value="11295">警慌失措</option>
# <option data-name="南巫" value="11258">南巫</option>
# <option data-name="當男人戀愛時" value="11255">當男人戀愛時</option>
# <option data-name="無名弒" value="11126">無名弒</option>
# <option data-name="波麗萊多里鬼屋" value="11242">波麗萊多里鬼屋</option>
# <option data-name="揭大歡喜" value="11171">揭大歡喜</option>
# <option data-name="花漾女子" value="10519">花漾女子</option>
# <option data-name="東經北緯" value="11222">東經北緯</option>
# <option data-name="刺殺小說家" value="11205">刺殺小說家</option>
# <option data-name="複身犯" value="11160">複身犯</option>
# <option data-name="我沒有談的那場戀愛" value="11159">我沒有談的那場戀愛</option>
# <option data-name="湯姆貓與傑利鼠" value="11072">湯姆貓與傑利鼠</option>
# <option data-name="角頭–浪流連" value="11162">角頭–浪流連</option>
# <option data-name="靈魂急轉彎" value="11089">靈魂急轉彎</option>
# <option data-name="汪星人的奇幻漂流" value="10388">汪星人的奇幻漂流</option>
# </select>

# %%
movie_item = movie_html.find_all("option",attrs={'data-name':re.compile('.*')})

# %%
title_list = []
id_list = []
#先宣告兩個list放電影標題跟電影ＩＤ
#因為moite_item 是一個bs4的元素集合，我們要用遍歷去探索它:
for info in movie_item:
     print(info)
     print(type(info))
     print("Movie: {}, ID: {}".format(info["data-name"], info["value"]))
    
     id_list.append(info["value"])
     title_list.append(info["data-name"])
     #然後我們把title 跟id 放進list中
# Out:
# <option data-name="玩命關頭9" value="10482">玩命關頭9</option>
# <class 'bs4.element.Tag'>
# Movie: 玩命關頭9, ID: 10482
# <option data-name="青春：第50屆日本全國高中棒球錦標賽" value="11450">青春：第50屆日本全國高中棒球錦標賽</option>
# <class 'bs4.element.Tag'>
# Movie: 青春：第50屆日本全國高中棒球錦標賽, ID: 11450
# <option data-name="甲子園：夢想競技場" value="11449">甲子園：夢想競技場</option>
# <class 'bs4.element.Tag'>
# Movie: 甲子園：夢想競技場, ID: 11449
# <option data-name="合法伴侶" value="11441">合法伴侶</option>
# <class 'bs4.element.Tag'>
# Movie: 合法伴侶, ID: 11441
# <option data-name="雙面薇若妮卡 經典數位修復" value="11425">雙面薇若妮卡 經典數位修復</option>
# <class 'bs4.element.Tag'>
# Movie: 雙面薇若妮卡 經典數位修復, ID: 11425
# <option data-name="人聲" value="11400">人聲</option>
# <class 'bs4.element.Tag'>
# Movie: 人聲, ID: 11400
# <option data-name="薄荷糖" value="11368">薄荷糖</option>
# <class 'bs4.element.Tag'>
# Movie: 薄荷糖, ID: 11368
# <option data-name="路卡的夏天" value="11268">路卡的夏天</option>
# <class 'bs4.element.Tag'>
# Movie: 路卡的夏天, ID: 11268
# <option data-name="驅魔禁區" value="11439">驅魔禁區</option>
# <class 'bs4.element.Tag'>
# Movie: 驅魔禁區, ID: 11439
# <option data-name="自殺突擊隊：集結" value="11328">自殺突擊隊：集結</option>
# <class 'bs4.element.Tag'>
# Movie: 自殺突擊隊：集結, ID: 11328
# <option data-name="怪奇大廈" value="11438">怪奇大廈</option>
# <class 'bs4.element.Tag'>
# Movie: 怪奇大廈, ID: 11438
# <option data-name="太陽出來之後" value="11435">太陽出來之後</option>
# <class 'bs4.element.Tag'>
# Movie: 太陽出來之後, ID: 11435
# <option data-name="理髮師的男人 經典數位修復" value="11429">理髮師的男人 經典數位修復</option>
# <class 'bs4.element.Tag'>
# Movie: 理髮師的男人 經典數位修復, ID: 11429
# <option data-name="破碎的瞬間" value="11421">破碎的瞬間</option>
# <class 'bs4.element.Tag'>
# Movie: 破碎的瞬間, ID: 11421
# <option data-name="罪之聲" value="11420">罪之聲</option>
# <class 'bs4.element.Tag'>
# Movie: 罪之聲, ID: 11420
# <option data-name="詭老" value="11409">詭老</option>
# <class 'bs4.element.Tag'>
# Movie: 詭老, ID: 11409
# <option data-name="淘寶少年" value="11396">淘寶少年</option>
# <class 'bs4.element.Tag'>
# Movie: 淘寶少年, ID: 11396
# <option data-name="小王子公主心" value="11389">小王子公主心</option>
# <class 'bs4.element.Tag'>
# Movie: 小王子公主心, ID: 11389
# <option data-name="LIP X LIP享受這世界的方法" value="11364">LIP X LIP享受這世界的方法</option>
# <class 'bs4.element.Tag'>
# Movie: LIP X LIP享受這世界的方法, ID: 11364
# <option data-name="叢林奇航" value="10315">叢林奇航</option>
# <class 'bs4.element.Tag'>
# Movie: 叢林奇航, ID: 10315
# <option data-name="極速引爆" value="11428">極速引爆</option>
# <class 'bs4.element.Tag'>
# Movie: 極速引爆, ID: 11428
# <option data-name="手捲煙" value="11424">手捲煙</option>
# <class 'bs4.element.Tag'>
# Movie: 手捲煙, ID: 11424
# <option data-name="群青戰記" value="11397">群青戰記</option>
# <class 'bs4.element.Tag'>
# Movie: 群青戰記, ID: 11397
# <option data-name="厲陰宅3：是惡魔逼我的" value="11376">厲陰宅3：是惡魔逼我的</option>
# <class 'bs4.element.Tag'>
# Movie: 厲陰宅3：是惡魔逼我的, ID: 11376
# <option data-name="花束般的戀愛" value="11391">花束般的戀愛</option>
# <class 'bs4.element.Tag'>
# Movie: 花束般的戀愛, ID: 11391
# <option data-name="貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年" value="11375">貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年</option>
# <class 'bs4.element.Tag'>
# Movie: 貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年, ID: 11375
# <option data-name="怪物奇兵 全新世代" value="11342">怪物奇兵 全新世代</option>
# <class 'bs4.element.Tag'>
# Movie: 怪物奇兵 全新世代, ID: 11342
# <option data-name="野蠻糾碴隊" value="11300">野蠻糾碴隊</option>
# <class 'bs4.element.Tag'>
# Movie: 野蠻糾碴隊, ID: 11300
# <option data-name="失控的審判" value="11201">失控的審判</option>
# <class 'bs4.element.Tag'>
# Movie: 失控的審判, ID: 11201
# <option data-name="黑寡婦" value="10397">黑寡婦</option>
# <class 'bs4.element.Tag'>
# Movie: 黑寡婦, ID: 10397
# <option data-name="玩命鈔劫" value="11340">玩命鈔劫</option>
# <class 'bs4.element.Tag'>
# Movie: 玩命鈔劫, ID: 11340
# <option data-name="死亡漩渦：奪魂鋸新遊戲" value="11311">死亡漩渦：奪魂鋸新遊戲</option>
# <class 'bs4.element.Tag'>
# Movie: 死亡漩渦：奪魂鋸新遊戲, ID: 11311
# <option data-name="名偵探柯南：緋色的彈丸" value="11206">名偵探柯南：緋色的彈丸</option>
# <class 'bs4.element.Tag'>
# Movie: 名偵探柯南：緋色的彈丸, ID: 11206
# <option data-name="一級任務" value="11346">一級任務</option>
# <class 'bs4.element.Tag'>
# Movie: 一級任務, ID: 11346
# <option data-name="真．鮫島事件" value="11338">真．鮫島事件</option>
# <class 'bs4.element.Tag'>
# Movie: 真．鮫島事件, ID: 11338
# <option data-name="永生戰" value="11073">永生戰</option>
# <class 'bs4.element.Tag'>
# Movie: 永生戰, ID: 11073
# <option data-name="殺戮輪迴" value="11327">殺戮輪迴</option>
# <class 'bs4.element.Tag'>
# Movie: 殺戮輪迴, ID: 11327
# <option data-name="私刑救援" value="11263">私刑救援</option>
# <class 'bs4.element.Tag'>
# Movie: 私刑救援, ID: 11263
# <option data-name="真人快打" value="11254">真人快打</option>
# <class 'bs4.element.Tag'>
# Movie: 真人快打, ID: 11254
# <option data-name="誰殺了大個子" value="11296">誰殺了大個子</option>
# <class 'bs4.element.Tag'>
# Movie: 誰殺了大個子, ID: 11296
# <option data-name="警慌失措" value="11295">警慌失措</option>
# <class 'bs4.element.Tag'>
# Movie: 警慌失措, ID: 11295
# <option data-name="南巫" value="11258">南巫</option>
# <class 'bs4.element.Tag'>
# Movie: 南巫, ID: 11258
# <option data-name="當男人戀愛時" value="11255">當男人戀愛時</option>
# <class 'bs4.element.Tag'>
# Movie: 當男人戀愛時, ID: 11255
# <option data-name="無名弒" value="11126">無名弒</option>
# <class 'bs4.element.Tag'>
# Movie: 無名弒, ID: 11126
# <option data-name="波麗萊多里鬼屋" value="11242">波麗萊多里鬼屋</option>
# <class 'bs4.element.Tag'>
# Movie: 波麗萊多里鬼屋, ID: 11242
# <option data-name="揭大歡喜" value="11171">揭大歡喜</option>
# <class 'bs4.element.Tag'>
# Movie: 揭大歡喜, ID: 11171
# <option data-name="花漾女子" value="10519">花漾女子</option>
# <class 'bs4.element.Tag'>
# Movie: 花漾女子, ID: 10519
# <option data-name="東經北緯" value="11222">東經北緯</option>
# <class 'bs4.element.Tag'>
# Movie: 東經北緯, ID: 11222
# <option data-name="刺殺小說家" value="11205">刺殺小說家</option>
# <class 'bs4.element.Tag'>
# Movie: 刺殺小說家, ID: 11205
# <option data-name="複身犯" value="11160">複身犯</option>
# <class 'bs4.element.Tag'>
# Movie: 複身犯, ID: 11160
# <option data-name="我沒有談的那場戀愛" value="11159">我沒有談的那場戀愛</option>
# <class 'bs4.element.Tag'>
# Movie: 我沒有談的那場戀愛, ID: 11159
# <option data-name="湯姆貓與傑利鼠" value="11072">湯姆貓與傑利鼠</option>
# <class 'bs4.element.Tag'>
# Movie: 湯姆貓與傑利鼠, ID: 11072
# <option data-name="角頭–浪流連" value="11162">角頭–浪流連</option>
# <class 'bs4.element.Tag'>
# Movie: 角頭–浪流連, ID: 11162
# <option data-name="靈魂急轉彎" value="11089">靈魂急轉彎</option>
# <class 'bs4.element.Tag'>
# Movie: 靈魂急轉彎, ID: 11089
# <option data-name="汪星人的奇幻漂流" value="10388">汪星人的奇幻漂流</option>
# <class 'bs4.element.Tag'>
# Movie: 汪星人的奇幻漂流, ID: 10388

# %%
df_movie_id = pd.DataFrame()
df_movie_id["電影"]=title_list
df_movie_id["ID"]=id_list

# %%
print(df_movie_id)
# Out:
#                                 電影     ID
# 0                            玩命關頭9  10482
# 1               青春：第50屆日本全國高中棒球錦標賽  11450
# 2                        甲子園：夢想競技場  11449
# 3                             合法伴侶  11441
# 4                    雙面薇若妮卡 經典數位修復  11425
# 5                               人聲  11400
# 6                              薄荷糖  11368
# 7                            路卡的夏天  11268
# 8                             驅魔禁區  11439
# 9                         自殺突擊隊：集結  11328
# 10                            怪奇大廈  11438
# 11                          太陽出來之後  11435
# 12                   理髮師的男人 經典數位修復  11429
# 13                           破碎的瞬間  11421
# 14                             罪之聲  11420
# 15                              詭老  11409
# 16                            淘寶少年  11396
# 17                          小王子公主心  11389
# 18               LIP X LIP享受這世界的方法  11364
# 19                            叢林奇航  10315
# 20                            極速引爆  11428
# 21                             手捲煙  11424
# 22                            群青戰記  11397
# 23                     厲陰宅3：是惡魔逼我的  11376
# 24                          花束般的戀愛  11391
# 25  貝加爾湖隱居札記：在這喧囂的世界，一個人到西伯利亞森林住半年  11375
# 26                       怪物奇兵 全新世代  11342
# 27                           野蠻糾碴隊  11300
# 28                           失控的審判  11201
# 29                             黑寡婦  10397
# 30                            玩命鈔劫  11340
# 31                     死亡漩渦：奪魂鋸新遊戲  11311
# 32                     名偵探柯南：緋色的彈丸  11206
# 33                            一級任務  11346
# 34                          真．鮫島事件  11338
# 35                             永生戰  11073
# 36                            殺戮輪迴  11327
# 37                            私刑救援  11263
# 38                            真人快打  11254
# 39                          誰殺了大個子  11296
# 40                            警慌失措  11295
# 41                              南巫  11258
# 42                          當男人戀愛時  11255
# 43                             無名弒  11126
# 44                         波麗萊多里鬼屋  11242
# 45                            揭大歡喜  11171
# 46                            花漾女子  10519
# 47                            東經北緯  11222
# 48                           刺殺小說家  11205
# 49                             複身犯  11160
# 50                       我沒有談的那場戀愛  11159
# 51                         湯姆貓與傑利鼠  11072
# 52                          角頭–浪流連  11162
# 53                           靈魂急轉彎  11089
# 54                        汪星人的奇幻漂流  10388

# %%
a='123'
b=1
print(a+str(b))
# Out:
# 1231
